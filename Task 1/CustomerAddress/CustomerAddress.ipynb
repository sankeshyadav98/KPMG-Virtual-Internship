# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-0ec6d930-9318-4982-ba2b-bc54c44bf7de" name="files[]" multiple disabled />
#      <output id="result-0ec6d930-9318-4982-ba2b-bc54c44bf7de">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Book4.xlsx to Book4.xlsx
# ...

# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
df=pd.read_excel('Book4.xlsx')
df.head()
# Out:
#    customer_id              address  ...    country property_valuation
# 0            1   060 Morning Avenue  ...  Australia                 10
# 1            2  6 Meadow Vale Court  ...  Australia                 10
# 2            4   0 Holy Cross Court  ...  Australia                  9
# 3            5  17979 Del Mar Point  ...  Australia                  4
# 4            6     9 Oakridge Court  ...  Australia                  9
#
# [5 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# customer_id           0
# address               0
# postcode              0
# state                 0
# country               0
# property_valuation    0
# dtype: int64

# %%
df['postcode'].plot()

# %%
df['country'].value_counts()
# Out:
# Australia    3999
# Name: country, dtype: int64

# %%
df.head(1)
# Out:
#    customer_id             address  ...    country property_valuation
# 0            1  060 Morning Avenue  ...  Australia                 10
#
# [1 rows x 6 columns]

# %%
final=pd.DataFrame({
    'customer_id':df['customer_id'],
    'address':df['address'],
    'postcode':df['postcode'],
    'state':df['state'],
    'country':df['country'],
    'property_valuation':df['property_valuation']

})
final.to_csv('./CustomerAddress.csv',index=False)
print(final.head(10))
# Out:
#    customer_id                  address  ...    country property_valuation
# 0            1       060 Morning Avenue  ...  Australia                 10
# 1            2      6 Meadow Vale Court  ...  Australia                 10
# 2            4       0 Holy Cross Court  ...  Australia                  9
# 3            5      17979 Del Mar Point  ...  Australia                  4
# 4            6         9 Oakridge Court  ...  Australia                  9
# 5            7         4 Delaware Trail  ...  Australia                  9
# 6            8      49 Londonderry Lane  ...  Australia                  4
# 7            9          97736 7th Trail  ...  Australia                 12
# 8           11     93405 Ludington Park  ...  Australia                  8
# 9           12  44339 Golden Leaf Alley  ...  Australia                  4
#
# [10 rows x 6 columns]

# %%
files.download('CustomerAddress.csv')
