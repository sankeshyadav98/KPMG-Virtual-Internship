# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-678a7afc-7fa6-466d-ab1d-1f3257f12248" name="files[]" multiple disabled />
#      <output id="result-678a7afc-7fa6-466d-ab1d-1f3257f12248">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Book3.xlsx to Book3.xlsx
# ...

# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
df=pd.read_excel('Book3.xlsx')
df.head()
# Out:
#    customer_id      first_name  ... owns_car tenure
# 0            1         Laraine  ...      Yes   11.0
# 1            2             Eli  ...      Yes   16.0
# 2            3           Arlin  ...      Yes   15.0
# 3            4          Talbot  ...       No    7.0
# 4            5  Sheila-kathryn  ...      Yes    8.0
#
# [5 rows x 13 columns]

# %%
df.isnull().sum()
# Out:
# customer_id                              0
# first_name                               0
# last_name                              125
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     87
# job_title                              506
# job_industry_category                  656
# wealth_segment                           0
# deceased_indicator                       0
# default                                302
# owns_car                                 0
# tenure                                  87
# dtype: int64

# %%
df['last_name']=df['last_name'].fillna(method='ffill')

# %%
df['DOB']=df['DOB'].fillna(method='ffill')

# %%
df['job_title'].value_counts()
# Out:
# Business Systems Development Analyst    45
# Social Worker                           44
# Tax Accountant                          44
# Internal Auditor                        42
# Legal Assistant                         41
#                                         ..
# Account Representative II                4
# Research Assistant III                   3
# Health Coach III                         3
# Health Coach I                           3
# Developer I                              1
# Name: job_title, Length: 195, dtype: int64

# %%
df['job_title']=df['job_title'].fillna(method='bfill')

# %%
df['job_industry_category'].value_counts()
# Out:
# Manufacturing         799
# Financial Services    774
# Health                602
# Retail                358
# Property              267
# IT                    223
# Entertainment         136
# Argiculture           113
# Telecommunications     72
# Name: job_industry_category, dtype: int64

# %%
df['job_industry_category']=df['job_industry_category'].fillna(method='ffill')

# %%
del df['default']

# %%
df['tenure'].mean()
# Out:
# 10.65704063378482

# %%
df['tenure'].hist()

# %%
df['tenure']=df['tenure'].fillna(df['tenure'].mean())

# %%
df['tenure'].hist()

# %%
df.head(1)
# Out:
#    customer_id first_name  last_name  ... deceased_indicator  owns_car tenure
# 0            1    Laraine  Medendorp  ...                  N       Yes   11.0
#
# [1 rows x 12 columns]

# %%
final=pd.DataFrame({
    'customer_id':df['customer_id'],
    'first_name':df['first_name'],
    'last_name':df['last_name'],
    'gender':df['gender'],
    'past_3_years_bike_related_purchases':df['past_3_years_bike_related_purchases'],
    'DOB':df['DOB'],
    'job_title':df['job_title'],
    'job_industry_category':df['job_industry_category'],
    'wealth_segment':df['wealth_segment'],
    'deceased_indicator':df['deceased_indicator'],
    'owns_car':df['owns_car'],
    'tenure':df['tenure']
})
final.to_csv('./Customerdemographics.csv',index=False)
print(final.head(10))
# Out:
#    customer_id      first_name  last_name  ... deceased_indicator  owns_car tenure
# 0            1         Laraine  Medendorp  ...                  N       Yes   11.0
# 1            2             Eli    Bockman  ...                  N       Yes   16.0
# 2            3           Arlin     Dearle  ...                  N       Yes   15.0
# 3            4          Talbot     Dearle  ...                  N        No    7.0
# 4            5  Sheila-kathryn     Calton  ...                  N       Yes    8.0
# 5            6            Curr  Duckhouse  ...                  N       Yes   13.0
# 6            7            Fina     Merali  ...                  N       Yes   11.0
# 7            8             Rod      Inder  ...                  N        No    7.0
# 8            9            Mala       Lind  ...                  N       Yes    8.0
# 9           10        Fiorenze    Birdall  ...                  N       Yes   20.0
#
# [10 rows x 12 columns]

# %%
from google.colab import files
files.download('Customerdemographics.csv')
